# %% [markdown]
# <a href="https://colab.research.google.com/github/jainanthan2005-eng/ipl-data-analysis/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
conn=sqlite3.connect("company.db")
cursor=conn.cursor()
print("Database created sucessfully")
# Out:
# Database created sucessfully

# %%
cursor.execute("""
CREATE TABLE employees(
  employee_id INTEGER PRIMARY KEY,
  name text,
  department_id integer
 )
""")
conn.commit()
print("Table created suceessfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipykernel_590/2680821579.py in <cell line: 0>()
# ----> 1 cursor.execute("""
#       2 CREATE TABLE employees(
#       3   employee_id INTEGER PRIMARY KEY,
#       4   name text,
#       5   department_id integer
#
# OperationalError: table employees already exists

# %%
cursor.execute("DROP TABLE employees")
conn.commit()
print("Table dropped sucessfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipykernel_590/2111405410.py in <cell line: 0>()
# ----> 1 cursor.execute("DROP TABLE employees")
#       2 conn.commit()
#       3 print("Table dropped sucessfully")
#
# OperationalError: no such table: employees

# %%
# Out:
# Table created sucessfully

# %%
cursor.executemany(
"INSERT INTO EMPLOYEES VALUES(?,?,?,?)",
[
   (1,"JAI",18),
   (2,"VIRAT",18),
   (3,"POLO",98),
   (4,"JOJO",78),
   (5,"GOGO",67)
   ]
)
conn.commit()
("Rrcords inserted sucessfully")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipykernel_590/3006758256.py in <cell line: 0>()
# ----> 1 cursor.executemany(
#       2 "INSERT INTO EMPLOYEES VALUES(?,?,?,?)",
#       3 [
#       4    (1,"JAI",18),
#       5    (2,"VIRAT",18),
#
# OperationalError: table EMPLOYEES has 3 columns but 4 values were supplied
