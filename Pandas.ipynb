# %%
import pandas as pd
a=[12,12,34,23]
b=pd.Series(a)
print(b)
print(b.index)
# Out:
# 0    12
# 1    12
# 2    34
# 3    23
# dtype: int64
# RangeIndex(start=0, stop=4, step=1)

# %%
import pandas as pd
a=[12,12,34,23]
b=["a","b","c","d"]
c=pd.Series(a,index=b)
print(c)
print(c.index)
# Out:
# a    12
# b    12
# c    34
# d    23
# dtype: int64
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
import pandas as pd
a=[23,45,35,35,35,36,17,17,18]
v=pd.Series(a)
print(v)
print(v.mean())
# Out:
# 0    23
# 1    45
# 2    35
# 3    35
# 4    35
# 5    36
# 6    17
# 7    17
# 8    18
# dtype: int64
# 29.0

# %%
import pandas as pd
a=[23,34,56,45,24]
b=pd.DataFrame(a)
print(b)
print(type(b))
# Out:
#     0
# 0  23
# 1  34
# 2  56
# 3  45
# 4  24
# <class 'pandas.core.frame.DataFrame'>

# %%
  import pandas as  pd
  details=[
      ["kohli",12,78000],
      ["aseron",12,89000],
      ["damoe",45,89000],
      ["hamw",24,78899]
  ]
  cols=["name","age","salary"]
  c=[18,19,20,21]

  b=pd.DataFrame(details,columns=cols,index=c)
  print(b)
# Out:
#       name  age  salary
# 18   kohli   12   78000
# 19  aseron   12   89000
# 20   damoe   45   89000
# 21    hamw   24   78899
